# %%
import pandas as pd
import numpy as np
df=pd.read_csv('laptop_data(1).csv')
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
for column in df.columns:
    print(df[column].value_counts())
    print("*"*50)
# Out:
# Unnamed: 0
# 0       1
# 856     1
# 874     1
# 873     1
# 872     1
#        ..
# 433     1
# 432     1
# 431     1
# 430     1
# 1302    1
# Name: count, Length: 1303, dtype: int64
# **************************************************
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64
# **************************************************
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64
# **************************************************
# Inches
# 15.6    665
# 14.0    197
# ...

# %%
df.drop(columns=['Unnamed: 0','ScreenResolution','Gpu','Weight'],inplace = True)

# %%
df['TypeName'] = df['TypeName'].replace('2 in 1 Convertible', 'Two in One Convertible')

# %%
df['GB'] = df['Ram'].str.extract('(\d+)').astype(int)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Hp\AppData\Local\Temp\ipykernel_5164\3441639530.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['GB'] = df['Ram'].str.extract('(\d+)').astype(int)

# %%
df['Size'] = df['Memory'].str.extract('(\d+)').astype(int)
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Hp\AppData\Local\Temp\ipykernel_5164\791987464.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['Size'] = df['Memory'].str.extract('(\d+)').astype(int)
#   Company   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                 Memory  OpSys        Price  GB  Size
# 0            128GB SSD  macOS   71378.6832   8   128
# 1  128GB Flash Storage  macOS   47895.5232   8   128
# 2            256GB SSD  No OS   30636.0000   8   256
# 3            512GB SSD  macOS  135195.3360  16   512
# 4            256GB SSD  macOS   96095.8080   8   256

# %%
df['CPU'] = df['Cpu'].str.split().str.slice(0, 3).str.join(' ')
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                 Memory  OpSys        Price  GB  Size            CPU
# 0            128GB SSD  macOS   71378.6832   8   128  Intel Core i5
# 1  128GB Flash Storage  macOS   47895.5232   8   128  Intel Core i5
# 2            256GB SSD  No OS   30636.0000   8   256  Intel Core i5
# 3            512GB SSD  macOS  135195.3360  16   512  Intel Core i7
# 4            256GB SSD  macOS   96095.8080   8   256  Intel Core i5

# %%
df.drop(columns=['Cpu','Ram','Memory'],inplace = True)

# %%
df
# Out:
#      Company                TypeName  Inches       OpSys        Price  GB  \
# 0      Apple               Ultrabook    13.3       macOS   71378.6832   8
# 1      Apple               Ultrabook    13.3       macOS   47895.5232   8
# 2         HP                Notebook    15.6       No OS   30636.0000   8
# 3      Apple               Ultrabook    15.4       macOS  135195.3360  16
# 4      Apple               Ultrabook    13.3       macOS   96095.8080   8
# ...      ...                     ...     ...         ...          ...  ..
# 1298  Lenovo  Two in One Convertible    14.0  Windows 10   33992.6400   4
# 1299  Lenovo  Two in One Convertible    13.3  Windows 10   79866.7200  16
# 1300  Lenovo                Notebook    14.0  Windows 10   12201.1200   2
# 1301      HP                Notebook    15.6  Windows 10   40705.9200   6
# 1302    Asus                Notebook    15.6  Windows 10   19660.3200   4
#
#       Size                 CPU
# 0      128       Intel Core i5
# ...

# %%
x=df[['Company','TypeName','Inches','OpSys','GB','Size','CPU']]
y=df[['Price']]

# %%
x
# Out:
#      Company                TypeName  Inches       OpSys  GB  Size  \
# 0      Apple               Ultrabook    13.3       macOS   8   128
# 1      Apple               Ultrabook    13.3       macOS   8   128
# 2         HP                Notebook    15.6       No OS   8   256
# 3      Apple               Ultrabook    15.4       macOS  16   512
# 4      Apple               Ultrabook    13.3       macOS   8   256
# ...      ...                     ...     ...         ...  ..   ...
# 1298  Lenovo  Two in One Convertible    14.0  Windows 10   4   128
# 1299  Lenovo  Two in One Convertible    13.3  Windows 10  16   512
# 1300  Lenovo                Notebook    14.0  Windows 10   2    64
# 1301      HP                Notebook    15.6  Windows 10   6     1
# 1302    Asus                Notebook    15.6  Windows 10   4   500
#
#                      CPU
# 0          Intel Core i5
# 1          Intel Core i5
# 2          Intel Core i5
# 3          Intel Core i7
# 4          Intel Core i5
# ...

# %%
y
# Out:
#             Price
# 0      71378.6832
# 1      47895.5232
# 2      30636.0000
# 3     135195.3360
# 4      96095.8080
# ...           ...
# 1298   33992.6400
# 1299   79866.7200
# 1300   12201.1200
# 1301   40705.9200
# 1302   19660.3200
#
# [1303 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#       Company                TypeName  Inches       OpSys  GB  Size  \
# 1249     Dell  Two in One Convertible    13.3  Windows 10   8   256
# 1186     Dell  Two in One Convertible    15.6  Windows 10  16   512
# 568    Lenovo                Notebook    15.6  Windows 10   4   500
# 1251       HP                Notebook    15.6  Windows 10   4   500
# 491   Toshiba               Ultrabook    13.3  Windows 10  32   512
# ...       ...                     ...     ...         ...  ..   ...
# 763      Asus               Ultrabook    13.3  Windows 10   8   256
# 835      Dell                  Gaming    15.6  Windows 10  16   256
# 1216     Acer                Notebook    17.3  Windows 10   4     1
# 559      Dell                Notebook    15.6  Windows 10   4     1
# 684    Lenovo  Two in One Convertible    13.3  Windows 10   8   512
#
#                      CPU
# 1249       Intel Core i5
# 1186       Intel Core i7
# 568   Intel Pentium Quad
# 1251  AMD A6-Series 9220
# ...

# %%
x_test
# Out:
#        Company                TypeName  Inches       OpSys  GB  Size  \
# 580   Mediacom                Notebook    14.0  Windows 10   4    32
# 1017    Lenovo                Notebook    17.3   Windows 7  16   512
# 761       Dell               Ultrabook    12.5  Windows 10  16   256
# 686         HP                Notebook    15.6  Windows 10   4   500
# 186       Dell                Notebook    15.6  Windows 10  16   512
# ...        ...                     ...     ...         ...  ..   ...
# 1176    Lenovo                Notebook    15.6   Windows 7   4     1
# 549     Lenovo                Notebook    15.6  Windows 10   8   512
# 922         HP               Ultrabook    13.3  Windows 10   8   256
# 399     Lenovo               Ultrabook    14.0  Windows 10  16     1
# 44        Dell  Two in One Convertible    17.3  Windows 10  12     1
#
#                      CPU
# 580   Intel Celeron Quad
# 1017       Intel Core i7
# 761        Intel Core i7
# 686        Intel Core i5
# ...

# %%
ohe=OneHotEncoder()
ohe.fit(x[['Company','TypeName','OpSys','CPU']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Company','TypeName','OpSys','CPU']), remainder='passthrough')

# %%
scaler=StandardScaler()
scaler = StandardScaler(with_mean=False)

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,scaler,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Acer', 'Apple', 'Asus', 'Chuwi', 'Dell', 'Fujitsu', 'Google',
#        'HP', 'Huawei', 'LG', 'Lenovo', 'MSI', 'Mediacom', 'Microsoft',
# ...

# %%
y_pred_lr=pipe.predict(x_test)

# %%
r2_score(y_test,y_pred_lr)
# Out:
# 0.7269313057271409

# %%
lasso=Lasso()
pipe=make_pipeline(column_trans,scaler,lasso)

# %%
pipe.fit(x_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:658: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22685776832.741547, tolerance: 135857493.52754435
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
# ...

# %%
y_pred_lasso=pipe.predict(x_test)
r2_score(y_test,y_pred_lasso)
# Out:
# 0.7267318848246875

# %%
#Ridge

# %%
ridge=Ridge()
pipe=make_pipeline(column_trans,scaler,ridge)

# %%
pipe.fit(x_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Acer', 'Apple', 'Asus', 'Chuwi', 'Dell', 'Fujitsu', 'Google',
#        'HP', 'Huawei', 'LG', 'Lenovo', 'MSI', 'Mediacom', 'Microsoft',
# ...

# %%
y_pred_ridge=pipe.predict(x_test)
r2_score(y_test,y_pred_ridge)
# Out:
# 0.7268746603136967

# %%
print("No regularization:",r2_score(y_test,y_pred_lr))
print("Lasso:",r2_score(y_test,y_pred_lasso))
print("Ridge:",r2_score(y_test,y_pred_ridge))
# Out:
# No regularization: 0.7269313057271409
# Lasso: 0.7267318848246875
# Ridge: 0.7268746603136967

# %%
import pickle

# %%
pickle.dump(pipe,open('Ridgemodel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Dell','Ultrabook',15,'Windows 10',5,32,'Intel Core i7']],columns=['Company','TypeName','Inches','OpSys','GB','Size','CPU']))
# Out:
# array([[59940.19762069]])
